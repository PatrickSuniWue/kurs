# %% [markdown]
# ## Lower heading

# %% [markdown]
# # Big heading

# %%
# %matplotlib inline

import numby as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
y = np.sin(x)
plt.plot(x, y, marker="x")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-abba901bb511> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2
# ----> 3 import numby as np
#       4 import matplotlib.pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'numby'

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
y = np.sin(x)
plt.plot(x, y, marker="x")

# %%
import pandas as pd

FNAME="http://www.stat.ucla.edu~rgould/datasets/twins.dat"

df = pd.read_csv((FNAME, sep='\T'))
# Out:
#   File "<ipython-input-3-4c7e868496c2>", line 5
#     df = pd.read_csv((FNAME, sep='\T'))
#                                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

FNAME = "http://www.stat.ucla.edu~rgould/datasets/twins.dat"

df = pd.read_csv((FNAME, sep='\T'))
# Out:
#   File "<ipython-input-4-0d215e8c0f22>", line 5
#     df = pd.read_csv((FNAME, sep='\T'))
#                                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

FNAME = "http://www.stat.ucla.edu~rgould/datasets/twins.dat"

df = pd.read_csv(FNAME, sep='\T')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# c:\program files (x86)\python37-32\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# c:\program files (x86)\python37-32\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# ...

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-633337079cd0> in <module>
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

FNAME = "http://www.stat.ucla.edu~rgould/datasets/twins.dat"

df = pd.read_csv(FNAME, sep='\T')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# c:\program files (x86)\python37-32\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# c:\program files (x86)\python37-32\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# ...

# %%
import pandas as pd

FNAME = "http://www.stat.ucla.edu/~rgould/datasets/twins.dat"

df = pd.read_csv(FNAME, sep='\t')
# Out:
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-728f3cb90f5b> in <module>
#       3 FNAME = "http://www.stat.ucla.edu/~rgould/datasets/twins.dat"
#       4
# ----> 5 df = pd.read_csv(FNAME, sep='\T')
#
# ...

# %%
import pandas as pd

FNAME = "http://www.stat.ucla.edu/~rgould/datasets/twins.dat"

df = pd.read_csv(FNAME, sep='\T')
# Out:
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-728f3cb90f5b> in <module>
#       3 FNAME = "http://www.stat.ucla.edu/~rgould/datasets/twins.dat"
#       4
# ----> 5 df = pd.read_csv(FNAME, sep='\T')
#
# ...

# %%
import pandas as pd

FNAME = "http://www.stat.ucla.edu/~rgould/datasets/twins.dat"

df = pd.read_csv(FNAME, sep='\t')

# %%
import pandas as pd

FNAME = "http://www.stat.ucla.edu/~rgould/datasets/twins.dat"

df = pd.read_csv(FNAME, sep='\T')
# Out:
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-728f3cb90f5b> in <module>
#       3 FNAME = "http://www.stat.ucla.edu/~rgould/datasets/twins.dat"
#       4
# ----> 5 df = pd.read_csv(FNAME, sep='\T')
#
# ...

# %%
import pandas as pd

FNAME = "http://www.stat.ucla.edu/~rgould/datasets/twins.dat"

df = pd.read_csv(FNAME, sep='\t')

# %%
import pandas as pd

FNAME = "http://www.stat.ucla.edu/~rgould/datasets/twins.dat"

df = pd.read_csv(FNAME, sep='\T')
# Out:
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-13-728f3cb90f5b> in <module>
#       3 FNAME = "http://www.stat.ucla.edu/~rgould/datasets/twins.dat"
#       4
# ----> 5 df = pd.read_csv(FNAME, sep='\T')
#
# ...

# %%
import pandas as pd

FNAME = "http://www.stat.ucla.edu/~rgould/datasets/twins.dat"

df = pd.read_csv(FNAME, sep='\t')

# %%
df.loc()

# %%
df.iloc[0]
# Out:
# DLHRWAGE      0.2593466
# DEDUC1                0
# AGE             33.2512
# AGESQ           1105.64
# LHRWAGEH    2.420368129
# WHITEH                1
# MALEH                 0
# EDUCH                16
# LHRWAGEL    2.161021529
# WHITEL                1
# MALEL                 0
# EDUCL                16
# DEDUC2                0
# DTEN              1.333
# DMARRIED              0
# DUNCOV                0
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# DLHRWAGE      0.2593466
# DEDUC1                0
# AGE             33.2512
# AGESQ           1105.64
# LHRWAGEH    2.420368129
# WHITEH                1
# MALEH                 0
# EDUCH                16
# LHRWAGEL    2.161021529
# WHITEL                1
# MALEL                 0
# EDUCL                16
# DEDUC2                0
# DTEN              1.333
# DMARRIED              0
# DUNCOV                0
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# DLHRWAGE              ?
# DEDUC1               -1
# AGE             54.0534
# AGESQ           2921.77
# LHRWAGEH              ?
# WHITEH                1
# MALEH                 0
# EDUCH                 9
# LHRWAGEL    2.060513532
# WHITEL                1
# MALEL                 0
# EDUCL                10
# DEDUC2                1
# DTEN                  8
# DMARRIED              1
# DUNCOV                0
# Name: 1, dtype: object

# %%
df.loc[4]
# Out:
# DLHRWAGE    -0.560984677
# DEDUC1                 0
# AGE              34.6338
# AGESQ             1199.5
# LHRWAGEH      2.26336598
# WHITEH                 1
# MALEH                  1
# EDUCH                 14
# LHRWAGEL     2.824350657
# WHITEL                 1
# MALEL                  1
# EDUCL                 14
# DEDUC2                 1
# DTEN               2.917
# DMARRIED               0
# DUNCOV                -1
# Name: 4, dtype: object

# %%
df.iloc[18, 2]
# Out:
# 39.34017796

# %%
df.loc[LRWAGEL]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-665b7df2441e> in <module>
# ----> 1 df.loc[LRWAGEL]
#
# NameError: name 'LRWAGEL' is not defined

# %%
df[DEDUC]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-08a49af13475> in <module>
# ----> 1 df[DEDUC]
#
# NameError: name 'DEDUC' is not defined

# %%
df[DEDUC1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-4e671ecf0d26> in <module>
# ----> 1 df[DEDUC1]
#
# NameError: name 'DEDUC1' is not defined

# %%
df.loc[0]
# Out:
# DLHRWAGE      0.2593466
# DEDUC1                0
# AGE             33.2512
# AGESQ           1105.64
# LHRWAGEH    2.420368129
# WHITEH                1
# MALEH                 0
# EDUCH                16
# LHRWAGEL    2.161021529
# WHITEL                1
# MALEL                 0
# EDUCL                16
# DEDUC2                0
# DTEN              1.333
# DMARRIED              0
# DUNCOV                0
# Name: 0, dtype: object

# %%
df["DEDUC1"]
# Out:
# 0      0
# 1     -1
# 2      7
# 3      0
# 4      0
#       ..
# 178    0
# 179    0
# 180    2
# 181   -2
# 182    0
# Name: DEDUC1, Length: 183, dtype: int64

# %%
df.loc[0]
# Out:
# DLHRWAGE      0.2593466
# DEDUC1                0
# AGE             33.2512
# AGESQ           1105.64
# LHRWAGEH    2.420368129
# WHITEH                1
# MALEH                 0
# EDUCH                16
# LHRWAGEL    2.161021529
# WHITEL                1
# MALEL                 0
# EDUCL                16
# DEDUC2                0
# DTEN              1.333
# DMARRIED              0
# DUNCOV                0
# Name: 0, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DLHRWAGE  183 non-null    object
#  1   DEDUC1    183 non-null    int64
#  2   AGE       183 non-null    float64
#  3   AGESQ     183 non-null    float64
#  4   LHRWAGEH  183 non-null    object
#  5   WHITEH    183 non-null    int64
#  6   MALEH     183 non-null    int64
#  7   EDUCH     183 non-null    int64
#  8   LHRWAGEL  183 non-null    object
#  9   WHITEL    183 non-null    int64
#  10  MALEL     183 non-null    int64
#  11  EDUCL     183 non-null    int64
#  12  DEDUC2    183 non-null    int64
#  13  DTEN      183 non-null    object
#  14  DMARRIED  183 non-null    int64
#  15  DUNCOV    182 non-null    float64
# dtypes: float64(3), int64(9), object(4)
# memory usage: 20.1+ KB

# %%
df["DMARRIED"] 0 df["DMARRIED"].astype(bool)
# Out:
#   File "<ipython-input-28-5801c7519b0e>", line 1
#     df["DMARRIED"] 0 df["DMARRIED"].astype(bool)
#                    ^
# SyntaxError: invalid syntax

# %%
df["DMARRIED"] = df["DMARRIED"].astype(bool)

# %%
df["WHITEH"] = df[WHITEH].astype("category")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-1904305ee69e> in <module>
# ----> 1 df["WHITEH"] = df[WHITEH].astype("category")
#
# NameError: name 'WHITEH' is not defined

# %%
df["WHITEH"] = df[WHITEH].astype("category")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1904305ee69e> in <module>
# ----> 1 df["WHITEH"] = df[WHITEH].astype("category")
#
# NameError: name 'WHITEH' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DLHRWAGE  183 non-null    object
#  1   DEDUC1    183 non-null    int64
#  2   AGE       183 non-null    float64
#  3   AGESQ     183 non-null    float64
#  4   LHRWAGEH  183 non-null    object
#  5   WHITEH    183 non-null    int64
#  6   MALEH     183 non-null    int64
#  7   EDUCH     183 non-null    int64
#  8   LHRWAGEL  183 non-null    object
#  9   WHITEL    183 non-null    int64
#  10  MALEL     183 non-null    int64
#  11  EDUCL     183 non-null    int64
#  12  DEDUC2    183 non-null    int64
#  13  DTEN      183 non-null    object
#  14  DMARRIED  183 non-null    bool
#  15  DUNCOV    182 non-null    float64
# dtypes: bool(1), float64(3), int64(8), object(4)
# memory usage: 18.8+ KB

# %%
df["WHITEL"]= df["WHITEH"].astype("category")

# %%
df["LHRWAGEH"]=pd.to_numeric(df["LHRWAGEH"], errors="coerce")

# %%
df.info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DLHRWAGE  183 non-null    object
#  1   DEDUC1    183 non-null    int64
#  2   AGE       183 non-null    float64
#  3   AGESQ     183 non-null    float64
#  4   LHRWAGEH  161 non-null    float64
#  5   WHITEH    183 non-null    int64
#  6   MALEH     183 non-null    int64
#  7   EDUCH     183 non-null    int64
#  8   LHRWAGEL  183 non-null    object
#  9   WHITEL    183 non-null    category
#  10  MALEL     183 non-null    int64
#  11  EDUCL     183 non-null    int64
#  12  DEDUC2    183 non-null    int64
#  13  DTEN      183 non-null    object
#  14  DMARRIED  183 non-null    bool
#  15  DUNCOV    182 non-null    float64
# dtypes: bool(1), category(1), float64(4), int64(7), object(3)
# memory usage: 18.4+ KB

# %%
bools=['WITEH', 'MALEH', 'WHITEL', 'MALEL']

# %%
df[bools]=df[bools].astype(bool)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-c74648ab2b71> in <module>
# ----> 1 df[bools]=df[bools].astype(bool)
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ...

# %%
df[bools] = df[bools].astype(bool)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-eb68838a1120> in <module>
# ----> 1 df[bools] = df[bools].astype(bool)
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ...

# %%
df[bools]=df[bools].astype(bool)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-c74648ab2b71> in <module>
# ----> 1 df[bools]=df[bools].astype(bool)
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ...

# %%
bools=['WHITEH', 'MALEH', 'WHITEL', 'MALEL']

# %%
df[bools]=df[bools].astype(bool)

# %%
df['DMARRIED']=df['DMARRIED'].astype('int8')

# %%
df.info(memory_usage=TRUE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-f74b6f82636d> in <module>
# ----> 1 df.info(memory_usage=TRUE)
#
# NameError: name 'TRUE' is not defined

# %%
df.info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DLHRWAGE  183 non-null    object
#  1   DEDUC1    183 non-null    int64
#  2   AGE       183 non-null    float64
#  3   AGESQ     183 non-null    float64
#  4   LHRWAGEH  161 non-null    float64
#  5   WHITEH    183 non-null    bool
#  6   MALEH     183 non-null    bool
#  7   EDUCH     183 non-null    int64
#  8   LHRWAGEL  183 non-null    object
#  9   WHITEL    183 non-null    bool
#  10  MALEL     183 non-null    bool
#  11  EDUCL     183 non-null    int64
#  12  DEDUC2    183 non-null    int64
#  13  DTEN      183 non-null    object
#  14  DMARRIED  183 non-null    int8
#  15  DUNCOV    182 non-null    float64
# dtypes: bool(4), float64(4), int64(4), int8(1), object(3)
# memory usage: 14.5+ KB

# %%
df[df["AGE"]>20]
df[(df["AGE"]>20)&(df["WHITEL"]==1)]
df[-df["AGE"]>20]
values = (20,21,22,23)
df[df["AGE"].isin(values)]
# Out:
# Empty DataFrame
# Columns: [DLHRWAGE, DEDUC1, AGE, AGESQ, LHRWAGEH, WHITEH, MALEH, EDUCH, LHRWAGEL, WHITEL, MALEL, EDUCL, DEDUC2, DTEN, DMARRIED, DUNCOV]
# Index: []

# %%
df[df["AGE"]>20]
# Out:
#          DLHRWAGE  DEDUC1        AGE        AGESQ  LHRWAGEH  WHITEH  MALEH  \
# 0       0.2593466       0  33.251198  1105.642156  2.420368    True  False
# 1               ?      -1  54.053388  2921.768764       NaN    True  False
# 2     0.721318058       7  43.570157  1898.358618  2.890372    True  False
# 3     0.011581964       0  30.967830   959.006511  2.803360    True   True
# 4    -0.560984677       0  34.633812  1199.500965  2.263366    True   True
# ..            ...     ...        ...          ...       ...     ...    ...
# 178   0.109904862       0  45.555099  2075.267067  3.025594    True  False
# 179             ?       0  26.376454   695.717351       NaN    True   True
# 180   0.850332764       2  40.312115  1625.066615  1.704748    True  False
# 181  -0.729514825      -2  28.413415   807.322179  2.014903    True  False
# 182  -0.500775288       0  28.413415   807.322179  2.197225    True  False
#
# ...

# %%
df[(df["AGE"]>20)&(df["WHITEL"]==1)]
# Out:
#          DLHRWAGE  DEDUC1        AGE        AGESQ  LHRWAGEH  WHITEH  MALEH  \
# 0       0.2593466       0  33.251198  1105.642156  2.420368    True  False
# 1               ?      -1  54.053388  2921.768764       NaN    True  False
# 2     0.721318058       7  43.570157  1898.358618  2.890372    True  False
# 3     0.011581964       0  30.967830   959.006511  2.803360    True   True
# 4    -0.560984677       0  34.633812  1199.500965  2.263366    True   True
# ..            ...     ...        ...          ...       ...     ...    ...
# 178   0.109904862       0  45.555099  2075.267067  3.025594    True  False
# 179             ?       0  26.376454   695.717351       NaN    True   True
# 180   0.850332764       2  40.312115  1625.066615  1.704748    True  False
# 181  -0.729514825      -2  28.413415   807.322179  2.014903    True  False
# 182  -0.500775288       0  28.413415   807.322179  2.197225    True  False
#
# ...

# %%
df[-df["AGE"]>20]
# Out:
# Empty DataFrame
# Columns: [DLHRWAGE, DEDUC1, AGE, AGESQ, LHRWAGEH, WHITEH, MALEH, EDUCH, LHRWAGEL, WHITEL, MALEL, EDUCL, DEDUC2, DTEN, DMARRIED, DUNCOV]
# Index: []

# %%
df[(-df["AGE"]>20)]
# Out:
# Empty DataFrame
# Columns: [DLHRWAGE, DEDUC1, AGE, AGESQ, LHRWAGEH, WHITEH, MALEH, EDUCH, LHRWAGEL, WHITEL, MALEL, EDUCL, DEDUC2, DTEN, DMARRIED, DUNCOV]
# Index: []

# %%
df[~(df["AGE"]>20)]
# Out:
#         DLHRWAGE  DEDUC1        AGE       AGESQ  LHRWAGEH  WHITEH  MALEH  \
# 57             0       0  19.898700  395.958243  1.791759    True   True
# 82   2.109746891       0  19.222450  369.502598  4.119662    True   True
# 173            0       0  18.781656  352.750617  1.446919    True  False
#
#      EDUCH     LHRWAGEL  WHITEL  MALEL  EDUCL  DEDUC2    DTEN  DMARRIED  \
# 57      13  1.791759469    True   True     13       0  -0.084         0
# 82      12  2.009915479    True   True     12       0    3.25         0
# 173     13  1.446918983    True  False     13       0  -0.083         0
#
#      DUNCOV
# 57      0.0
# 82      0.0
# 173     0.0

# %%
values = (20,21,22,23)

# %%
df[df["AGE"].isin(values)]
# Out:
# Empty DataFrame
# Columns: [DLHRWAGE, DEDUC1, AGE, AGESQ, LHRWAGEH, WHITEH, MALEH, EDUCH, LHRWAGEL, WHITEL, MALEL, EDUCL, DEDUC2, DTEN, DMARRIED, DUNCOV]
# Index: []

# %%
df["WHITEL"]==1)
# Out:
#   File "<ipython-input-53-8cc3329925f8>", line 1
#     df["WHITEL"]==1)
#                    ^
# SyntaxError: invalid syntax

# %%
df[(df["WHITEL"]==0)]
# Out:
#          DLHRWAGE  DEDUC1        AGE        AGESQ  LHRWAGEH  WHITEH  MALEH  \
# 23     -0.3254224       0  21.349760   455.812271  1.871802   False   True
# 30    2.014903021       0  61.872690  3828.229760  3.624341   False   True
# 36   -0.478035801      -6  39.619439  1569.699926  2.740840   False   True
# 37    1.034073768       0  22.072553   487.197598  2.931194   False   True
# 43    0.600437783       0  44.232717  1956.533281  3.729701   False  False
# 72    -0.51366603      -1  33.590691  1128.334543  2.420368   False  False
# 73    0.167054085       0  32.290212  1042.657803  3.481240   False  False
# 88    0.014888613       0  29.185489   851.792791  2.317474   False   True
# 100             ?      -4  62.579055  3916.138180       NaN   False   True
# 149             ?      -1  64.459959  4155.086306       NaN   False  False
# 154   0.619039208      -7  31.208761   973.986771  2.564949   False  False
# ...

# %%
df.shape[(df["WHITEL"]==0)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-9457988728e2> in <module>
# ----> 1 df.shape[(df["WHITEL"]==0)]
#
# TypeError: tuple indices must be integers or slices, not Series

# %%
df.shape[(df["WHITEL"]==0)].shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-9ee0ffcc918e> in <module>
# ----> 1 df.shape[(df["WHITEL"]==0)].shape
#
# TypeError: tuple indices must be integers or slices, not Series

# %%
df[(df["WHITEL"]==0)].shape
# Out:
# (12, 16)

# %%
df[(df["WHITEL"]==1)&(df["DEDUC1"]!=0)].shape
# Out:
# (89, 16)

# %%
df[(df["WHITEL"]==0)].shape
# Out:
# (12, 16)

# %%
df[(df["WHITEH"]==0)] != df["WHITEL"]].shape
# Out:
#   File "<ipython-input-61-5168cd09df50>", line 1
#     df[(df["WHITEH"]==0)] != df["WHITEL"]].shape
#                                          ^
# SyntaxError: invalid syntax

# %%
df[df["WHITEH"]==0)] != df["WHITEL"]].shape
# Out:
#   File "<ipython-input-62-31bb245a37bc>", line 1
#     df[df["WHITEH"]==0)] != df["WHITEL"]].shape
#                       ^
# SyntaxError: invalid syntax

# %%
df[df["WHITEH"]==0 !=  df["WHITEL"]].shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-cc5db8fdf89f> in <module>
# ----> 1 df[df["WHITEH"]==0 !=  df["WHITEL"]].shape
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[df["WHITEH"] !=  df["WHITEL"]].shape
# Out:
# (0, 16)

# %%
df["AGE"].descr
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-61ecb6266aed> in <module>
# ----> 1 df["AGE"].descr
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'descr'

# %%
df["AGE"].describe
# Out:
# <bound method NDFrame.describe of 0      33.251198
# 1      54.053388
# 2      43.570157
# 3      30.967830
# 4      34.633812
#          ...
# 178    45.555099
# 179    26.376454
# 180    40.312115
# 181    28.413415
# 182    28.413415
# Name: AGE, Length: 183, dtype: float64>

# %%
df[df["WHITEH"]==0)]["AGE"].describe
# Out:
#   File "<ipython-input-67-2b87ce6e8927>", line 1
#     df[df["WHITEH"]==0)]["AGE"].describe
#                       ^
# SyntaxError: invalid syntax

# %%
["AGE"].describe if df["WHITEL"]==1
# Out:
#   File "<ipython-input-68-0d73e4137b72>", line 1
#     ["AGE"].describe if df["WHITEL"]==1
#                                        ^
# SyntaxError: invalid syntax

# %%
mask=(df["WHITEL"] !=0) & (df["MALE"]==1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MALE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-80de0876d087> in <module>
# ...

# %%
mask=(df["WHITEL"]!=1)&(df["MALE"]==1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MALE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-f4de87ea4042> in <module>
# ...

# %%
mask=(df["WHITEL"]!=1)&(df["MALEL"]==1)

# %%
df.iloc[mask,"AGE"].mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-72-bda47e91fb50> in <module>
# ----> 1 df.iloc[mask,"AGE"].mean()
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2064     def _getitem_tuple(self, tup: Tuple):
#    2065
# -> 2066         self._has_valid_tuple(tup)
#    2067         try:
#    2068             return self._getitem_lowerdim(tup)
#
# ...

# %%
df.iloc[mask,"AGE"].describe()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-73-72c17958f9d3> in <module>
# ----> 1 df.iloc[mask,"AGE"].describe()
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2064     def _getitem_tuple(self, tup: Tuple):
#    2065
# -> 2066         self._has_valid_tuple(tup)
#    2067         try:
#    2068             return self._getitem_lowerdim(tup)
#
# ...

# %%
df.loc[mask,"AGE"].mean()
# Out:
# 39.65033734285714

# %%
df["WHITEL"].value_counts()
# Out:
# True     171
# False     12
# Name: WHITEL, dtype: int64

# %%
pd.crosstab(df["WHITEH"], df["WHITEL"])
# Out:
# WHITEL  False  True
# WHITEH
# False      12      0
# True        0    171

# %%
df[["DEDUC2", "EDUCL"]].corr()
# Out:
#           DEDUC2     EDUCL
# DEDUC2  1.000000 -0.280353
# EDUCL  -0.280353  1.000000

# %%
df["EDUCL"].value_counts()
# Out:
# 12    61
# 16    37
# 14    29
# 13    21
# 15    11
# 18    10
# 10     4
# 20     3
# 19     3
# 17     1
# 11     1
# 8      1
# 1      1
# Name: EDUCL, dtype: int64

# %%
pd.crosstab(df["MALEH"], df["MALEL"])
# Out:
# MALEL  False  True
# MALEH
# False     99      0
# True       0     84

# %%
df[["EDUCH", "EDUCL"]].corr()
# Out:
#        EDUCH  EDUCL
# EDUCH  1.000  0.628
# EDUCL  0.628  1.000

# %%
df[["EDUCH", "EDUCL"]].pearson()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-26042a783c05> in <module>
# ----> 1 df[["EDUCH", "EDUCL"]].pearson()
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'pearson'

# %%
df[["EDUCH", "EDUCL"]].spearman()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-7f6530a0cc15> in <module>
# ----> 1 df[["EDUCH", "EDUCL"]].spearman()
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'spearman'

# %%
df[["EDUCH", "EDUCL"]].corr(method=="pearson")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-fa7856e939a7> in <module>
# ----> 1 df[["EDUCH", "EDUCL"]].corr(method=="pearson")
#
# NameError: name 'method' is not defined

# %%
df[["EDUCH", "EDUCL"]].corr("pearson")
# Out:
#        EDUCH  EDUCL
# EDUCH  1.000  0.628
# EDUCL  0.628  1.000

# %%
df["EDUCH"].info(memory_usage=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-68e2b221760d> in <module>
# ----> 1 df["EDUCH"].info(memory_usage=True)
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
df[["EDUCH", "EDUCL"]].info())
# Out:
#   File "<ipython-input-86-922d8a7e4602>", line 1
#     df[["EDUCH", "EDUCL"]].info())
#                                  ^
# SyntaxError: invalid syntax

# %%
df=df.dropna(subset=["HRWAGEH"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-b335c48a59f0> in <module>
# ----> 1 df=df.dropna(subset=["HRWAGEH"])
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4746             check = indices == -1
#    4747             if check.any():
# -> 4748                 raise KeyError(list(np.compress(check, subset)))
#    4749             agg_obj = self.take(indices, axis=agg_axis)
#    4750
#
# KeyError: ['HRWAGEH']

# %%
df=df.dropna(subset=["HRWAGEH"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-b335c48a59f0> in <module>
# ----> 1 df=df.dropna(subset=["HRWAGEH"])
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4746             check = indices == -1
#    4747             if check.any():
# -> 4748                 raise KeyError(list(np.compress(check, subset)))
#    4749             agg_obj = self.take(indices, axis=agg_axis)
#    4750
#
# KeyError: ['HRWAGEH']

# %%
df['combined']=df['MALEH']+df['EDUCH']

# %%
df['AGETR']=df['AGE']**3

# %%
df['new']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-ff32c5992877> in <module>
# ----> 1 df['new']
#
# ...

# %%
df['new']=9

# %%
df=df[sorted(df.columns)]

# %%
df=df.sort_values(by='HRWAGEH')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-a3ca933d9d24> in <module>
# ----> 1 df=df.sort_values(by='HRWAGEH')
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'HRWAGEH'

# %%
df.info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AGE       183 non-null    float64
#  1   AGESQ     183 non-null    float64
#  2   AGETR     183 non-null    float64
#  3   DEDUC1    183 non-null    int64
#  4   DEDUC2    183 non-null    int64
#  5   DLHRWAGE  183 non-null    object
#  6   DMARRIED  183 non-null    int8
#  7   DTEN      183 non-null    object
#  8   DUNCOV    182 non-null    float64
#  9   EDUCH     183 non-null    int64
#  10  EDUCL     183 non-null    int64
#  11  LHRWAGEH  161 non-null    float64
#  12  LHRWAGEL  183 non-null    object
#  13  MALEH     183 non-null    bool
#  14  MALEL     183 non-null    bool
#  15  WHITEH    183 non-null    bool
#  16  WHITEL    183 non-null    bool
#  17  combined  183 non-null    int64
#  18  new       183 non-null    int64
# dtypes: bool(4), float64(5), int64(6), int8(1), object(3)
# ...

# %%
df=df.sort_values(by='LHRWAGEH')

# %%
df["LHRWAGEH_new"]=df["LHRWAGE"].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LHRWAGE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-873aeddb366f> in <module>
# ...

# %%
df["LHRWAGEH_new"]=df["LHRWAGEH"].fillna(0)

# %%
df=df.dropna(subset=["LHRWAGE"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-f845a8c6920a> in <module>
# ----> 1 df=df.dropna(subset=["LHRWAGE"])
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4746             check = indices == -1
#    4747             if check.any():
# -> 4748                 raise KeyError(list(np.compress(check, subset)))
#    4749             agg_obj = self.take(indices, axis=agg_axis)
#    4750
#
# KeyError: ['LHRWAGE']

# %%
df=df.dropna(subset=["LHRWAGEH"])

# %%
grouped=df.groupby(['MALEH'])

# %%
print(grouped['AGE'].mean())
# Out:
# MALEH
# False    36.055111
# True     37.923953
# Name: AGE, dtype: float64

# %%
print(grouped['EDUCH]').agg(['mean','sum']))
# Out:
#   File "<ipython-input-103-b565c53f83c0>", line 1
#     print(grouped['EDUCH]').agg(['mean','sum']))
#                           ^
# SyntaxError: invalid syntax

# %%
print(grouped['EDUCH').agg(['mean','sum']))
# Out:
#   File "<ipython-input-104-6786198daec2>", line 1
#     print(grouped['EDUCH').agg(['mean','sum']))
#                          ^
# SyntaxError: invalid syntax

# %%
print(grouped['EDUCH').agg(['mean', 'sum']))
# Out:
#   File "<ipython-input-105-2f5e8a04f232>", line 1
#     print(grouped['EDUCH').agg(['mean', 'sum']))
#                          ^
# SyntaxError: invalid syntax

# %%
print(grouped['EDUCH'].agg(['mean', 'sum']))
# Out:
#             mean   sum
# MALEH
# False  13.917647  1183
# True   14.092105  1071

# %%
print(grouped['EDUCH','AGE']].agg(['mean', 'std'])
# Out:
#   File "<ipython-input-107-25b358493759>", line 1
#     print(grouped['EDUCH','AGE']].agg(['mean', 'std'])
#                                 ^
# SyntaxError: invalid syntax

# %%
print(grouped[['EDUCH','AGE']].agg(['mean', 'std']))
# Out:
#            EDUCH                  AGE
#             mean       std       mean        std
# MALEH
# False  13.917647  2.274139  36.055111   9.749019
# True   14.092105  2.240105  37.923953  12.326690

# %%
print(grouped[['AGE','MALEL']].agg(['mean', 'std']))
# Out:
#              AGE             MALEL
#             mean        std   mean  std
# MALEH
# False  36.055111   9.749019  False  0.0
# True   37.923953  12.326690   True  0.0

# %%
grouped=df.groupby(['MALEL'])

# %%
print(grouped[['AGE','MALEL']].agg(['mean'], 'std'))
# Out:
#              AGE  MALEL
#             mean   mean
# MALEL
# False  36.055111  False
# True   37.923953   True

# %%
print(grouped[['AGE','MALEL']].agg(['std'))
# Out:
#   File "<ipython-input-112-29e5a34c077d>", line 1
#     print(grouped[['AGE','MALEL']].agg(['std'))
#                                              ^
# SyntaxError: invalid syntax

# %%
print(grouped[['AGE','MALEL']].agg(['std']))
# Out:
#              AGE MALEL
#              std   std
# MALEL
# False   9.749019   0.0
# True   12.326690   0.0

# %%
groupA=df.groupby(['MALEL'])

# %%
print(groupA)['AGE'].std
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-e152434a746a> in <module>
# ----> 1 print(groupA)['AGE'].std
#
# TypeError: 'NoneType' object is not subscriptable

# %%
print(groupA)['AGE'].agg(['std'])
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-eaf3cc733066> in <module>
# ----> 1 print(groupA)['AGE'].agg(['std'])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
print(groupA)['AGE'].agg(std)
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-9308dc2470c6> in <module>
# ----> 1 print(groupA)['AGE'].agg(std)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
print(groupA)['AGE'].std()
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-2417634bdc98> in <module>
# ----> 1 print(groupA)['AGE'].std()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
print(groupA['AGE'].std())
# Out:
# MALEL
# False     9.749019
# True     12.326690
# Name: AGE, dtype: float64

# %%
print(groupA)["EDUCL"].quantile(q=[0.25,0.75]))
# Out:
#   File "<ipython-input-120-7ab941b1db99>", line 1
#     print(groupA)["EDUCL"].quantile(q=[0.25,0.75]))
#                                                   ^
# SyntaxError: invalid syntax

# %%
print(groupA)["EDUCL"].quantile(q=[0.25,0.75])
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-121-ceec455cc233> in <module>
# ----> 1 print(groupA)["EDUCL"].quantile(q=[0.25,0.75])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
print(groupA)["EDUCL"].quantile(q=[0.5, 0.75])]
# Out:
#   File "<ipython-input-122-3622d15c4e09>", line 1
#     print(groupA)["EDUCL"].quantile(q=[0.5, 0.75])]
#                                                   ^
# SyntaxError: invalid syntax

# %%
print(groupA["EDUCL"].quantile(q=[0.5, 0.75])]
# Out:
#   File "<ipython-input-123-ed67d106f657>", line 1
#     print(groupA["EDUCL"].quantile(q=[0.5, 0.75])]
#                                                  ^
# SyntaxError: invalid syntax

# %%
print(groupA["EDUCL"].quantile(q=[0.50, 0.75])]
# Out:
#   File "<ipython-input-124-71fe3e35ad10>", line 1
#     print(groupA["EDUCL"].quantile(q=[0.50, 0.75])]
#                                                   ^
# SyntaxError: invalid syntax

# %%
print(groupA["EDUCL"].quantile(q=[0.50, 0.75]))
# Out:
# MALEL
# False  0.50    14.0
#        0.75    16.0
# True   0.50    14.0
#        0.75    16.0
# Name: EDUCL, dtype: float64

# %%
groupb=df.groupby(['MALEL', 'MALEH'])

# %%
print(groupb['AGE']).mean()
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-ea766864a3d1> in <module>
# ----> 1 print(groupb['AGE']).mean()
#
# AttributeError: 'NoneType' object has no attribute 'mean'

# %%
print(groupb['AGE']).mean())
# Out:
#   File "<ipython-input-128-c4fc704f86f2>", line 1
#     print(groupb['AGE']).mean())
#                                ^
# SyntaxError: invalid syntax

# %%
print(groupb['AGE'].mean())
# Out:
# MALEL  MALEH
# False  False    36.055111
# True   True     37.923953
# Name: AGE, dtype: float64

# %%
# %matplotlib inline

# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.DataFrame{{
    'name': [],
    'age':[],
    'gender':[],
    'citizenship':[]
    'years_academia':[]
}}
# Out:
#   File "<ipython-input-3-25a90bfd367e>", line 1
#     df = pd.DataFrame{{
#                      ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame({
    'name': [],
    'age':[],
    'gender':[],
    'citizenship':[]
    'years_academia':[]
    )}
# Out:
#   File "<ipython-input-4-4fe247ce95f1>", line 6
#     'years_academia':[]
#                    ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame({
    'name': [],
    'age':[],
    'gender':[],
    'citizenship':[]
    'years_academia':[]
})
# Out:
#   File "<ipython-input-5-6b7adfab17a5>", line 6
#     'years_academia':[]
#                    ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame({
    'name': [],
    'age':[],
    'gender':[],
    'citizenship':[]
    'years_academia':[]
    })
# Out:
#   File "<ipython-input-6-b82474f13e0d>", line 6
#     'years_academia':[]
#                    ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame({
    'name': [],
    'age':[],
    'gender':[],
    'citizenship':[]
    'years_academia':[]
    })
# Out:
#   File "<ipython-input-7-b82474f13e0d>", line 6
#     'years_academia':[]
#                    ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame({
    'name': ["Michael", "Tobisas", "Patrick", "Filippo", "Patricia"],
    'age': [31, 30, 29, 26],
    'gender'["m", "m", "m", "m", "f"],
    'citizenship':["ger", "ger", "ger", "ch", "ch"]
    'years_academia':[7, 2.5, 3.8, 3, 0.9]
    })
# Out:
#   File "<ipython-input-8-d592571e9aa8>", line 4
#     'gender'["m", "m", "m", "m", "f"],
#                                      ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame({
    'name': ["Michael", "Tobisas", "Patrick", "Filippo", "Patricia"],
    'age': [31, 30, 29, 26],
    'gender':["m", "m", "m", "m", "f"],
    'citizenship':["ger", "ger", "ger", "ch", "ch"]
    'years_academia':[7, 2.5, 3.8, 3, 0.9]
    })
# Out:
#   File "<ipython-input-9-93ed81c39de5>", line 6
#     'years_academia':[7, 2.5, 3.8, 3, 0.9]
#                    ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame({
    'name': ["Michael", "Tobisas", "Patrick", "Filippo", "Patricia"],
    'age': [31, 30, 29, 26],
    'gender':["m", "m", "m", "m", "f"],
    'citizenship':["ger", "ger", "ger", "ch", "ch"],
    'years_academia':[7, 2.5, 3.8, 3, 0.9]
    })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-eec3fa26a68e> in <module>
#       4     'gender':["m", "m", "m", "m", "f"],
#       5     'citizenship':["ger", "ger", "ger", "ch", "ch"],
# ----> 6     'years_academia':[7, 2.5, 3.8, 3, 0.9]
#       7     })
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
# ...

# %%
df = pd.DataFrame({
    'name': ["Michael", "Tobisas", "Patrick", "Filippo", "Patricia"],
    'age': [31, 30, 29, 29, 26],
    'gender':["m", "m", "m", "m", "f"],
    'citizenship':["ger", "ger", "ger", "ch", "ch"],
    'years_academia':[7, 2.5, 3.8, 3, 0.9]
    })

# %%
df.plot.scatter{x="age", y="years_academia"}
# Out:
#   File "<ipython-input-12-7b0f5cdfb2db>", line 1
#     df.plot.scatter{x="age", y="years_academia"}
#                    ^
# SyntaxError: invalid syntax

# %%
df.plot.bar(x="name", y="age")

# %%
df.plot.scatter(x="age", y="years_academia")

# %%
df.plot.line()

# %%
df.plot.line(x='name', y='years_academia')

# %%
df.plot.line(x='name', y='years_academia', style=".")

# %%
df.plot.line(marker="O")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     288             try:
# --> 289                 Path(marker)
#     290                 self._marker_function = self._set_vertices
#
# c:\program files (x86)\python37-32\lib\site-packages\matplotlib\path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     126         """
# --> 127         vertices = _to_unmasked_float_array(vertices)
#     128         if vertices.ndim != 2 or vertices.shape[1] != 2:
#
# c:\program files (x86)\python37-32\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1316     else:
# -> 1317         return np.asarray(x, float)
#    1318
#
# ...

# %%
df.plot.line(marker=".")

# %%
df.plot.bar(x="name", y="age", color="r")

# %%
df.plot.bar(x="name", y="age", color="#ffdead")

# %%
df.plot.line(marker=".", colors=["age", "black"])
# Out:
#   File "<ipython-input-22-72691b47946f>", line 1
#     df.plot.line(marker="."), colors=("age", "black")
#                                                      ^
# SyntaxError: can't assign to function call

# %%
df.plot.line(marker=".", colors=["age", "black"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-802defdbbbc7> in <module>
# ----> 1 df.plot.line(marker=".", colors=["age", "black"])
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#     916             >>> lines = df.plot.line(x='pig', y='horse')
#     917         """
# --> 918         return self(kind="line", x=x, y=y, **kwargs)
#     919
#     920     def bar(self, x=None, y=None, **kwargs):
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ...

# %%
import matplotlob.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-2be623b03825> in <module>
# ----> 1 import matplotlob.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlob'

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplotss()
df.plot.line(x='name', y='years_academia, ax=ax)
# Out:
#   File "<ipython-input-26-b0b0ccf5d16e>", line 2
#     df.plot.line(x='name', y='years_academia, ax=ax)
#                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
fig, ax = plt.subplots()
df.plot.line(x='name', y='years_academia', ax=ax)

# %%
print(dir(ax))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_add_text', '_adjustable', '_agg_filter', '_alpha', '_anchor', '_animated', '_aspect', '_autoscaleXon', '_autoscaleYon', '_autotitlepos', '_axes', '_axes_class', '_axes_locator', '_axisbelow', '_clipon', '_clippath', '_contains', '_convert_dx', '_current_image', '_default_contains', '_facecolor', '_frameon', '_gci', '_gen_axes_patch', '_gen_axes_spines', '_get_axis_list', '_get_axis_map', '_get_clipping_extent_bbox', '_get_lines', '_get_patches_for_fill', '_get_view', '_gid', '_gridOn', '_in_layout', '_init_axis', '_label', '_layoutbox', '_left_title', '_make_twin_axes', '_mouseover', '_mouseover_set', '_navigate
# ...

# %%
plt.savefig("test.pdf")

# %%
plt.savefig("test.pdf")

# %%
fig.savefig("test.pdf")

# %%
#Changing the font
plt.rtParams["font.family"]="Comic Sans MS"
fig, ax = plt.subplots()
df.plot.line(x='name', y='years_academia', ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-e886707bd662> in <module>
#       1 #Changing the font
# ----> 2 plt.rtParams["font.family"]="Comic Sans MS"
#       3 fig, ax = plt.subplots()
#       4 df.plot.line(x='name', y='years_academia', ax=ax)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'rtParams'

# %%
#Changing the font
plt.rcParams["font.family"]="Comic Sans MS"
fig, ax = plt.subplots()
df.plot.line(x='name', y='years_academia', ax=ax)

# %%
plt.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df.plot.line(x='name', y='years_academia', ax=ax)
df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
ax.set(title="Example", xticketlabels=dfdf['name']),
xlabel="Students", ylabel="Years in Academia"
ax.legend(loc="upper left", titel="Legend")
# Out:
#   File "<ipython-input-35-76377c0e75b7>", line 5
#     xlabel="Students", ylabel="Years in Academia"
#           ^
# SyntaxError: can't assign to literal

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df.plot.line(x='name', y='years_academia', ax=ax)
df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
ax.set(title="Example", xticketlabels=dfdf['name'],
xlabel="Students", ylabel="Years in Academia")
ax.legend(loc="upper left", titel="Legend")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e11b9cff2560> in <module>
#       2 df.plot.line(x='name', y='years_academia', ax=ax)
#       3 df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
# ----> 4 ax.set(title="Example", xticketlabels=dfdf['name'],
#       5 xlabel="Students", ylabel="Years in Academia")
#       6 ax.legend(loc="upper left", titel="Legend")
#
# NameError: name 'dfdf' is not defined

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df.plot.line(x='name', y='years_academia', ax=ax)
df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
ax.set(title="Example", xticketlabels=dfdf['name'],
    xlabel="Students", ylabel="Years in Academia")
ax.legend(loc="upper left", titel="Legend")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-5569f955a9f1> in <module>
#       2 df.plot.line(x='name', y='years_academia', ax=ax)
#       3 df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
# ----> 4 ax.set(title="Example", xticketlabels=dfdf['name'],
#       5     xlabel="Students", ylabel="Years in Academia")
#       6 ax.legend(loc="upper left", titel="Legend")
#
# NameError: name 'dfdf' is not defined

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df.plot.line(x='name', y='years_academia', ax=ax)
df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
ax.set(title="Example", xticketlabels=df['name'],
    xlabel="Students", ylabel="Years in Academia")
ax.legend(loc="upper left", titel="Legend")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-91dc9b968c69> in <module>
#       3 df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
#       4 ax.set(title="Example", xticketlabels=df['name'],
# ----> 5     xlabel="Students", ylabel="Years in Academia")
#       6 ax.legend(loc="upper left", titel="Legend")
#
# c:\program files (x86)\python37-32\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1099             sorted(kwargs.items(), reverse=True,
#    1100                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
# -> 1101         return self.update(props)
#    1102
#    1103     def findobj(self, match=None, include_self=True):
#
# c:\program files (x86)\python37-32\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df.plot.line(x='name', y='years_academia', ax=ax)
df.plot.line(x='name', y='age', color="red", style=".", ax=ax)
ax.set(title="Example", xticketlabels=df['name'],
    xlabel="Students", ylabel="Years in Academia")
ax.legend(loc="upper left", titel="Legend")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-75c07d2e2c1f> in <module>
#       3 df.plot.line(x='name', y='age', color="red", style=".", ax=ax)
#       4 ax.set(title="Example", xticketlabels=df['name'],
# ----> 5     xlabel="Students", ylabel="Years in Academia")
#       6 ax.legend(loc="upper left", titel="Legend")
#
# c:\program files (x86)\python37-32\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1099             sorted(kwargs.items(), reverse=True,
#    1100                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
# -> 1101         return self.update(props)
#    1102
#    1103     def findobj(self, match=None, include_self=True):
#
# c:\program files (x86)\python37-32\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df.plot.line(x='name', y='years_academia', ax=ax)
df.plot.line(x='name', y='age', color="red", style="-." ax=ax)
ax.set(title="Example", xticklabels=df['name'],
    xlabel="Students", ylabel="Years in Academia")
ax.legend(loc="upper left", titel="Legend")
# Out:
#   File "<ipython-input-40-8e95492baecd>", line 3
#     df.plot.line(x='name', y='age', color="red", style="-." ax=ax)
#                                                              ^
# SyntaxError: invalid syntax

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df.plot.line(x='name', y='years_academia', ax=ax)
df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
ax.set(title="Example", xticklabels=df['name'],
    xlabel="Students", ylabel="Years in Academia")
ax.legend(loc="upper left", titel="Legend")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-4f153dc55b88> in <module>
#       4 ax.set(title="Example", xticklabels=df['name'],
#       5     xlabel="Students", ylabel="Years in Academia")
# ----> 6 ax.legend(loc="upper left", titel="Legend")
#
# c:\program files (x86)\python37-32\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     399         if len(extra_args):
#     400             raise TypeError('legend only accepts two non-keyword arguments')
# --> 401         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     402         self.legend_._remove_method = self._remove_legend
#     403         return self.legend_
#
# TypeError: __init__() got an unexpected keyword argument 'titel'

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df.plot.line(x='name', y='years_academia', ax=ax)
df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
ax.set(title="Example", xticklabels=df['name'],
    xlabel="Students", ylabel="Years in Academia")
ax.legend(loc="upper left", title="Legend")

# %%
ax.get_legend_handels_labels()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-6c538cd9df58> in <module>
# ----> 1 ax.get_legend_handels_labels()
#
# AttributeError: 'AxesSubplot' object has no attribute 'get_legend_handels_labels'

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df.plot.line(x='name', y='years_academia', ax=ax)
df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
ax.set(title="Example", xticklabels=df['name'],
    xlabel="Students", ylabel="Years in Academia")
ax.legend(loc="upper left", title="Legend")

# %%
grouped = df.groupby(['citizenship', 'gender'])['age'].size()
grouped.head()
# Out:
# citizenship  gender
# ch           f         1
#              m         1
# ger          m         3
# Name: age, dtype: int64

# %%
grouped.T.plot.bat(stacked=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-f2d0a589f4bd> in <module>
# ----> 1 grouped.T.plot.bat(stacked=True)
#
# AttributeError: 'PlotAccessor' object has no attribute 'bat'

# %%
grouped.T.plot.bar(stacked=True)

# %%
grouped = grouped.unstack()
grouped.T
# Out:
# citizenship   ch  ger
# gender
# f            1.0  NaN
# m            1.0  3.0

# %%
grouped.T.plot.bar(stacked=True)

# %%
grouped.T.plot.bar(stacked=False)

# %%
grouped.plot.barh()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df.plot.line(x='name', y='years_academia', ax=ax, label="years spent in academia")
df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
ax.set(title="Example", xticklabels=df['name'],
    xlabel="Students", ylabel="Years in Academia")
ax.legend(loc="upper left", title="Values")

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df.plot.line(x='name', y='years_academia', ax=ax, label="years spent in academia")
df.plot.line(x='name', y='age', color="red", style="-.", ax=ax)
ax.set(title="Example", xticklabels=df['name'],
    xlabel="Students", ylabel="Years in Academia")
ax.legend(loc="upper left", title="Values")

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-f800760e4e3d> in <module>
# ----> 1 tips=sns.load_dataset("tips")
#       2 tips.head()
#
# NameError: name 'sns' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid", palette="Set2")

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
tips["day"].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-578c94ad563c> in <module>
# ----> 1 sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
#
# NameError: name 'sns' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid", palette="Set2")

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-578c94ad563c> in <module>
# ----> 1 sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
#
# NameError: name 'tips' is not defined

# %%
tips["day"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9601ee534655> in <module>
# ----> 1 tips["day"].unique()
#
# NameError: name 'tips' is not defined

# %%
tips["day"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9601ee534655> in <module>
# ----> 1 tips["day"].unique()
#
# NameError: name 'tips' is not defined

# %%
tips=sns.load_dataset("tips")
tips["sex"].unique()
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kinds="line")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-051ba1640f2b> in <module>
# ----> 1 sns.relplot(x="total_bill", y="tip", data=tips, kinds="line")
#
# c:\program files (x86)\python37-32\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1700     g.map_dataframe(func, x, y,
#    1701                     hue=hue, size=size, style=style,
# -> 1702                     **plot_kws)
#    1703
#    1704     # Show the legend
#
# c:\program files (x86)\python37-32\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     831
#     832             # Draw the plot
# --> 833             self._facet_plot(func, ax, args, kwargs)
# ...

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
sns.__version__
# Out:
# '0.10.0'

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.0 KB

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid", palette="Set2")

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", palette="Set2")

# %%
tips=sns.load_dataset("tips")
tips["sex"].unique()
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="day", style="sex")

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="line")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="day", style="sex")
##requieres long format

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, col="day", hue="day", style="sex")
## col: you can also specify column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-e600ba631b5f> in <module>
# ----> 1 sns.scatterplot(x="total_bill", y="tip", data=tips, col="day", hue="day", style="sex")
#       2 ## col: you can also specify column
#
# c:\program files (x86)\python37-32\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1406         ax = plt.gca()
#    1407
# -> 1408     p.plot(ax, kwargs)
#    1409
#    1410     return ax
#
# c:\program files (x86)\python37-32\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     916         # function will advance the axes property cycle.
#     917
# --> 918         scout = ax.scatter([], [], **kws)
# ...

# %%
sns.relplot(x="total_bill", y="tip", data=tips, col="day", hue="day", style="sex")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-65dc437a49f8> in <module>
# ----> 1 sns.replot(x="total_bill", y="tip", data=tips, col="day", hue="day", style="sex")
#
# AttributeError: module 'seaborn' has no attribute 'replot'

# %%
sns.relplot(x="total_bill", y="tip", data=tips, col="day", hue="day", style="sex")

# %%
sns.relplot(x="total_bill", y="tip", data=tips, col="day", row="sex", hue="day")

# %%
fmri = sns.load_dataset("fmri")
print(fmri.head)
# Out:
# <bound method NDFrame.head of      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]>

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri, hue="region")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
sns.relplot(x="timepoint", y="signal", data=fmri, hue="region")

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri, hue="region")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734             try:
# --> 735                 result = self._python_apply_general(f)
#     736             except TypeError:
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750     def _python_apply_general(self, f):
# --> 751         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     752
#
# c:\program files (x86)\python37-32\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     205             group_axes = group.axes
# --> 206             res = f(group)
#     207             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
sns.relplot(x="timepoint", y="signal", hue="event" kind="line", data=fmri,
            ci="sd", styles="event", markers=True
# Out:
#   File "<ipython-input-31-95a915bf74b4>", line 1
#     sns.relplot(x="timepoint", y="signal", hue="event" kind="line", data=fmri,
#                                                           ^
# SyntaxError: invalid syntax

# %%
sns.relplot(x="timepoint", y="signal", hue="event" kind="scatter", data=fmri,
            ci="sd", styles="event", markers=True
# Out:
#   File "<ipython-input-32-5bb40ba0d92e>", line 1
#     sns.relplot(x="timepoint", y="signal", hue="event" kind="scatter", data=fmri,
#                                                           ^
# SyntaxError: invalid syntax

# %%
sns.catplot(x="day", y="total_bill", data=tips)

# %%
sns.catplot(x="day", y="total_bill", data=tips, palette="viridis")

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="swarm")

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="box")

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="boxen")

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="violin")

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="violin")
sns.catplot(x="day", y="total_bill", data=tips, kind="swarm", ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-623ab0066303> in <module>
#       1 sns.catplot(x="day", y="total_bill", data=tips, kind="violin")
# ----> 2 sns.catplot(x="day", y="total_bill", data=tips, kind="swarm", ax=ax)
#
# NameError: name 'ax' is not defined

# %%
ax= sns.catplot(x="day", y="total_bill", data=tips, kind="violin")
sns.catplot(x="day", y="total_bill", data=tips, kind="swarm", ax=ax)
# Out:
# c:\program files (x86)\python37-32\lib\site-packages\seaborn\categorical.py:3720: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try swarmplot
#   warnings.warn(msg, UserWarning)

# %%
sns.regplot(x="total_bill", y="tip", data=tips, marker=".")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-be70005a3a14> in <module>
# ----> 1 sns.regplot(x="total_bill", y="tip", data=tips, marker=".")
#
# c:\program files (x86)\python37-32\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     816     scatter_kws["marker"] = marker
#     817     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 818     plotter.plot(ax, scatter_kws, line_kws)
#     819     return ax
#     820
#
# c:\program files (x86)\python37-32\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     363
#     364         if self.fit_reg:
# ...

# %%
sns.regplot(x="total_bill", y="tip", data=tips, marker=".", logx=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-f98355d79dcd> in <module>
# ----> 1 sns.regplot(x="total_bill", y="tip", data=tips, marker=".", logx=True)
#
# c:\program files (x86)\python37-32\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     816     scatter_kws["marker"] = marker
#     817     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 818     plotter.plot(ax, scatter_kws, line_kws)
#     819     return ax
#     820
#
# c:\program files (x86)\python37-32\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     363
#     364         if self.fit_reg:
# ...

# %%
sns.regplot(x="total_bill", y="tip", data=tips, logx=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-2f2e498ceed1> in <module>
# ----> 1 sns.regplot(x="total_bill", y="tip", data=tips, logx=True)
#
# c:\program files (x86)\python37-32\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     816     scatter_kws["marker"] = marker
#     817     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 818     plotter.plot(ax, scatter_kws, line_kws)
#     819     return ax
#     820
#
# c:\program files (x86)\python37-32\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     363
#     364         if self.fit_reg:
# ...

# %%
sns.heatmap(tips[["total_bill"]])

# %%
sns.heatmap(tips[["day"].value_counts().to_frame])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-012c0362caa0> in <module>
# ----> 1 sns.heatmap(tips[["day"].value_counts().to_frame])
#
# AttributeError: 'list' object has no attribute 'value_counts'

# %%
sns.heatmap(tips[["day"].value_counts().to_frame])
# Out:
#   File "<ipython-input-46-557577f350b7>", line 1
#     sns.heatmap(tips[["day"].value_counts().to_frame())
#                                                       ^
# SyntaxError: invalid syntax

# %%
sns.heatmap(tips["day"].value_counts().to_frame])
# Out:
#   File "<ipython-input-47-d1e6259769c0>", line 1
#     sns.heatmap(tips["day"].value_counts().to_frame])
#                                                    ^
# SyntaxError: invalid syntax

# %%
sns.heatmap(tips["day"].value_counts().to_frame())

# %%
sns.heatmap(tips["day"].value_counts().to_frame())
plt.savefig("heatmap.png")

# %%
capitals={'germany': 'berlin', 'austria': 'vienna'}
print(capitals['france'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-4591e1cfa41b> in <module>
#       1 capitals={'germany': 'berlin', 'austria': 'vienna'}
# ----> 2 print(capitals['france'])
#
# KeyError: 'france'

# %%
my_list="fbcead"
my_list.sort()

##here sorting does not work on strings...it can work on lists
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-3cf0d858d7e1> in <module>
#       1 my_list="fbcead"
# ----> 2 my_list.sort()
#
# AttributeError: 'str' object has no attribute 'sort'

# %%
average=sum(a_list)/len(a_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-620dd66372ed> in <module>
# ----> 1 average=sum(a_list)/len(a_list)
#
# NameError: name 'a_list' is not defined
